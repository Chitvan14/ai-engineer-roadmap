# %% [markdown]
# <a href="https://colab.research.google.com/github/Chitvan14/ai-engineer-roadmap/blob/main/Day01_Personal_AI_Profile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Chitvan"

print(f"Welcome {name}!")

# %%
test = "arab"
print(f"new {test}!")

# %%
numbers = [2, 4, 6, 8]

squared = [n * n for n in numbers]

print(squared)

# %%
sumtest=[2,3,4,5]

sum = [n + 1 for n in sumtest]

print(sum)

# %%
def greet(name):
    return f"Hello {name}"

print(greet("AI Engineer"))

# %%
name="Chitvan"
role="SDE"
experience="30"
Goal="learning"

def printing(name,role,experience,Goal):
    return f"Hi, I'm {name}.\n\nI'm currently a {role}.\n\nMy goal is to become an AI Engineer in {experience} days.\n\n{Goal}"


print(printing(name,role,experience,Goal))
# Out:
# Hi, I'm Chitvan.
#
# I'm currently a SDE.
#
# My goal is to become an AI Engineer in 30 days.
#
# learning
